# %%
from pprint import pprint
meu_dicionário = { "nome":"camilly","sobrenome": "camilly", "idade": 21, "peso": 57, "filhos": ["maria", "joaozinho", "pedrinho"]} 
# pprint(meu_dicionário)

print(meu_dicionário ["idade"])
# Out:
# 21
