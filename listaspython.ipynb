# %%
list_example = [1,2,3]
list_example.append(4)
list_example.pop()
print(list_example)
# Out:
# [1, 2, 3]

# %%
list_x = ["e", "c", "a", "d", "b"]
list_x.sort()
print(list_x)
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
list_y = ["a", "b", "c", "d", "e"]
list_y.reverse()
print(list_y)
# Out:
# ['e', 'd', 'c', 'b', 'a']

# %%
list_a = ["e", "c", "a", "d", "b"]
list_a.insert("0","z")

print(list_a)
